# %% [markdown]
# ### Problem 12: Highly Divisible Triangular Number
# <p>The sequence of triangle numbers is generated by adding the natural numbers. So the $7$<sup>th</sup> triangle number would be $1 + 2 + 3 + 4 + 5 + 6 + 7 = 28$. The first ten terms would be:
# $$1, 3, 6, 10, 15, 21, 28, 36, 45, 55, \dots$$</p>
# <p>Let us list the factors of the first seven triangle numbers:</p>
# \begin{align}
# \mathbf 1 &\colon 1\\
# \mathbf 3 &\colon 1,3\\
# \mathbf 6 &\colon 1,2,3,6\\
# \mathbf{10} &\colon 1,2,5,10\\
# \mathbf{15} &\colon 1,3,5,15\\
# \mathbf{21} &\colon 1,3,7,21\\
# \mathbf{28} &\colon 1,2,4,7,14,28
# \end{align}
# <p>We can see that $28$ is the first triangle number to have over five divisors.</p>
# <p>What is the value of the first triangle number to have over five hundred divisors?</p>

# %%
import sympy
import math
import time

# %%
def sum_numbers_to(n):
    return int(n*(n+1)/2)

# %%
def pe_12():
    n = 1
    while True:
        if len(sympy.divisors(sum_numbers_to(n))) > 500: return sum_numbers_to(n)
        n+=1

# %%
time_start = time.perf_counter()
res = pe_12()
time_end = time.perf_counter()
time_taken = time_end - time_start
print(f'The answer is : {res}\nTime taken : {time_taken:6f}s')
# Out:
# The answer is : 76576500
# Time taken : 0.887333s
